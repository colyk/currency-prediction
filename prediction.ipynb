# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
data = pd.read_csv('currency_data')
data.head()
# Out:
#    Unnamed: 0       PLN
# 0  2019-02-05  3.753130
# 1  2018-12-19  3.755633
# 2  2019-07-15  3.782234
# 3  2018-11-29  3.768859
# 4  2018-12-05  3.771887

# %%
rolmean = data.rolling(window=12).mean()
rolstd = data.rolling(window=12).std()

data.plot(color='blue',label='Original')
rolmean.plot(color='red', label='Rolling Mean')
rolstd.plot(color='black', label = 'Rolling Std')
plt.legend(loc='best')

# %%
data['PLN']
# Out:
# 0      3.753130
# 1      3.755633
# 2      3.782234
# 3      3.768859
# 4      3.771887
#          ...
# 250    3.791767
# 251    3.756592
# 252    3.787784
# 253    3.823728
# 254    3.897621
# Name: PLN, Length: 255, dtype: float64

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(data['PLN'])
model_fit = model.fit()
prediction = model_fit.predict(len(data), len(data))
print(prediction)
# Out:
# 255    3.897086
# dtype: float64

# %%
model_fit?
